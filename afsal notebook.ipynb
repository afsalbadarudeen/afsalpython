# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Mohammed Afsal B
#  Data Scientist in Biological Research Field

# %% [markdown]
#  _I am interested in data science because it is a well demanding career and it can create a lot of impact in all the sectors._

# %% [markdown]
# ### The below cell should print 5+3

# %%
print(5+3)
# Out:
# 8

# %% [markdown]
# 1 Afsal 97
# - adil ~89~
